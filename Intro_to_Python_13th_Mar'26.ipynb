# %% [markdown]
# <a href="https://colab.research.google.com/github/gs19891908-cmd/Demo/blob/main/Intro_to_Python_13th_Mar'26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# We are learning about **Python**
#
# 1. Data Types
# 2. Data Structure
# - List
# - Array
# 3. Liabraries
# 4. Data Analysis
# - Pandas
# - Numpy
# 5. Data Visualization
# - MetaplotLib
# - Seaborn
# 6. Basic Descriptive Analysis
# - head()
# - describe()

# %%
print("Hello world")
# Out:
# Hello world

# %%
x=2
y=3

# %%
print(x*y)
# Out:
# 6

# %% [markdown]
# **Data Type**
#
# * Int
# * Float
# * Boolean
# * String

# %%
a=2
print(a)
print(type(a))
# Out:
# 2
# <class 'int'>

# %%
b=2.2
print(b)
print(type(b))
# Out:
# 2.2
# <class 'float'>

# %%
c='Gaurav' #Alphabet (strings always in double or single quotes)
print(c)
print(type(c))
# Out:
# Gaurav
# <class 'str'>

# %%
d=True # Boolean value ie True or false ()
print(d)
print(type(d))
# Out:
# True
# <class 'bool'>

# %%
print(a,"-",b,"-",c,"-",d)
# Out:
# 2 - 2.2 - Gaurav - True

# %% [markdown]
# **Data Structures**
#
# * List
# * Array

# %%
#List = Collection of Dissimilar data types

list_1=[a,b,c,d]
print(list_1)
print(type(list_1))
# Out:
# [2, 2.2, 'Gaurav', True]
# <class 'list'>

# %%
list_2=['Bahubali','RRR','Dhurandhar','Chak De India']
print(list_2)
print(type(list_2))
# Out:
# ['Bahubali', 'RRR', 'Dhurandhar', 'Chak De India']
# <class 'list'>

# %%
#Array = Collection of smae data types
import numpy as np

array_1 = np.array(list_1)
print(array_1)
print(type(array_1))
# Out:
# ['2' '2.2' 'Gaurav' 'True']
# <class 'numpy.ndarray'>

# %%
array_2 = np.array([1,4.2])
print(array_2)
print(type(array_2))
# Out:
# [1.  4.2]
# <class 'numpy.ndarray'>

# %% [markdown]
# **Liabraries/Packages**
#
# Piece of Python code open-sourcedto the world so that it can be reused.

# %%
#numpy = Numerical Calculation
#pandas = Data manipulation (similar to excel - add/delete rows & columns, subset, formulated columns)
#metplotlib = Visualization
#Seaborn = Advance Visualization, built on top Metaplotlib

# %%
import pandas as pd

# Reading csv/excel file as dataframe(DF) in Python

TMKOC_DF = pd.read_csv("/content/TMKOC 1.csv")
display(TMKOC_DF)
# Out:
#              Name  Age  Married  Height
# 0        Jethalal   54     True     5.6
# 1           Tappu   18    False     5.1
# 2         Babbita   32     True     5.8
# 3  Champak Chacha   68     True     5.4
# 4        Dr Hathi   57     True     5.3

# %%
#Differnce of visulization while usinf display or print
print(TMKOC_DF)
# Out:
#              Name  Age  Married  Height
# 0        Jethalal   54     True     5.6
# 1           Tappu   18    False     5.1
# 2         Babbita   32     True     5.8
# 3  Champak Chacha   68     True     5.4
# 4        Dr Hathi   57     True     5.3
